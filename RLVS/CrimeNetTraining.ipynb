# %% [markdown]
# # Install Modules

# %%
pip install opencv-python
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install tensorflow==2.10.0
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install neural-structured-learning
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# # Check GPU Available

# %%
import tensorflow as tf

tf.config.list_physical_devices('GPU')
# Out:
# 2024-03-29 14:36:35.467651: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2024-03-29 14:36:35.561385: E tensorflow/stream_executor/cuda/cuda_blas.cc:2981] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-03-29 14:36:35.997015: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer.so.7'; dlerror: libnvinfer.so.7: cannot open shared object file: No such file or directory
# ...

# %% [markdown]
# # Import Script To Training

# %%
import NSL_2D_RLVS.py
# Out:
# Loading Training: /home/user/work/data/RLVS/NonViolence/NV_606.mp4
# Loading Training: /home/user/work/data/RLVS/NonViolence/NV_970.mp4
# Loading Training: /home/user/work/data/RLVS/Violence/V_810.mp4
# Loading Training: /home/user/work/data/RLVS/Violence/V_9.mp4
# Loading Training: /home/user/work/data/RLVS/Violence/V_895.mp4
# Loading Training: /home/user/work/data/RLVS/Violence/V_46.mp4
# Loading Training: /home/user/work/data/RLVS/Violence/V_938.mp4
# Loading Training: /home/user/work/data/RLVS/NonViolence/NV_835.mp4
# Loading Training: /home/user/work/data/RLVS/NonViolence/NV_164.mp4
# Loading Training: /home/user/work/data/RLVS/NonViolence/NV_432.mp4
# Loading Training: /home/user/work/data/RLVS/NonViolence/NV_180.mp4
# Loading Training: /home/user/work/data/RLVS/Violence/V_949.mp4
# Loading Training: /home/user/work/data/RLVS/Violence/V_53.mp4
# Loading Training: /home/user/work/data/RLVS/Violence/V_578.mp4
# Loading Training: /home/user/work/data/RLVS/Violence/V_538.mp4
# ...
